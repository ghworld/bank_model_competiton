# %%
from sklearn.model_selection import train_test_split
import pandas as pd 

# help(train_test_split)

# %%
train_input_path = 'train.csv'
test_input_path  = 'testaa.csv'

df_train = pd.read_csv(train_input_path)

print(df_train.shape)
# sample_data  = df_train.sample(frac = 2.0)
# print(sample_data.shape)


sample_data_x      = df_train.drop(['label'], axis = 1)
sample_data_target = df_train['label'].values
# Out:
# (53480, 19)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25808\4241414497.py in <module>
#       5
#       6 print(df_train.shape)
# ----> 7 sample_data  = df_train.sample(frac = 2.0)
#       8 print(sample_data.shape)
#       9
#
# d:\users\chenchen\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    5347         elif frac is not None and frac > 1 and not replace:
#    5348             raise ValueError(
# -> 5349                 "Replace has to be set to `True` when "
#    5350                 "upsampling the population `frac` > 1."
#    5351             )
#
# ValueError: Replace has to be set to `True` when upsampling the population `frac` > 1.

# %%
# from sklearn.over_sampling import SMOTE
from sklearn.utils import resample

y = [0, 0, 1, 1, 1, 1, 1, 1, 1]
resample(y, n_samples=5, replace=False, stratify=y,random_state=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25808\1448468730.py in <module>
#       3
#       4 y = [0, 0, 1, 1, 1, 1, 1, 1, 1]
# ----> 5 resample(y, n_samples=100, replace=False, stratify=y,random_state=0)
#
# d:\users\chenchen\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\__init__.py in resample(replace, n_samples, random_state, stratify, *arrays)
#     549         raise ValueError(
#     550             "Cannot sample %d out of arrays with dim %d when replace is False"
# --> 551             % (max_n_samples, n_samples)
#     552         )
#     553
#
# ValueError: Cannot sample 100 out of arrays with dim 9 when replace is False

# %%
X_train, X_test, y_train, y_test = train_test_split(sample_data_x, sample_data_target, test_size=0.2, random_state=10, shuffle=True)

ids_str = ",".join(list(map(str, X_test['id'].values)))
hash(ids_str)
# Out:
# True

# %%
from sklearn.ensemble import GradientBoostingClassifier
help(GradientBoostingClassifier)
# Out:
# Help on class GradientBoostingClassifier in module sklearn.ensemble._gb:
#
# class GradientBoostingClassifier(sklearn.base.ClassifierMixin, BaseGradientBoosting)
#  |  GradientBoostingClassifier(*, loss='deviance', learning_rate=0.1, n_estimators=100, subsample=1.0, criterion='friedman_mse', min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_depth=3, min_impurity_decrease=0.0, init=None, random_state=None, max_features=None, verbose=0, max_leaf_nodes=None, warm_start=False, validation_fraction=0.1, n_iter_no_change=None, tol=0.0001, ccp_alpha=0.0)
#  |
#  |  Gradient Boosting for classification.
#  |
#  |  GB builds an additive model in a
#  |  forward stage-wise fashion; it allows for the optimization of
#  |  arbitrary differentiable loss functions. In each stage ``n_classes_``
#  |  regression trees are fit on the negative gradient of the
#  |  binomial or multinomial deviance loss function. Binary classification
# ...
